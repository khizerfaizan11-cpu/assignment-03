# %% [markdown]
# ## Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
# Using \n for new lines and \t for neat alignment
print("Name:\t\tkhizer faizan\nFather's Name:\tfaizan riaz\nDate of Birth:\tjuly 04, 2010")
# Out:
# Name:		khizer faizan
# Father's Name:	faizan riaz
# Date of Birth:	july 04, 2010

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
# Defining the variables
name = "khizer"
age = 16
hobby = "coding and playing football"
favorite_subject = "Computer Science"

# Printing the bio using the print function
print("--- My Bio ---")
print("Name:", name)
print("Age:", age)
print("Hobby:", hobby)
print("Favorite Subject:", favorite_subject)
print("--------------")
# Out:
# --- My Bio ---
# Name: khizer
# Age: 16
# Hobby: coding and playing football
# Favorite Subject: Computer Science
# --------------

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
# Python Operators Example

a = 10
b = 3

# 1. Arithmetic Operators
print("Arithmetic Operators")
print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", a / b)
print("a // b =", a // b)
print("a % b =", a % b)
print("a ** b =", a ** b)

# 2. Assignment Operators
print("\nAssignment Operators")
x = 5
x += 2
print("x += 2:", x)
x -= 1
print("x -= 1:", x)
x *= 3
print("x *= 3:", x)
x /= 2
print("x /= 2:", x)

# 3. Comparison Operators
print("\nComparison Operators")
print("a == b:", a == b)
print("a != b:", a != b)
print("a > b:", a > b)
print("a < b:", a < b)
print("a >= b:", a >= b)
print("a <= b:", a <= b)

# 4. Logical Operators
print("\nLogical Operators")
print(a > 5 and b < 5)
print(a > 5 or b > 5)
print(not (a > b))
# Out:
# Arithmetic Operators
# a + b = 13
# a - b = 7
# a * b = 30
# a / b = 3.3333333333333335
# a // b = 3
# a % b = 1
# a ** b = 1000
#
# Assignment Operators
# x += 2: 7
# x -= 1: 6
# x *= 3: 18
# x /= 2: 9.0
#
# Comparison Operators
# a == b: False
# a != b: True
# a > b: True
# a < b: False
# a >= b: True
# a <= b: False
#
# Logical Operators
# True
# True
# False

# %% [markdown]
# 4. Completes the following steps of small task:
# Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
# Mention Variable of Total Marks and assign 300 to it
# Calculate Percentage

# %%
# Marks of three subjects
english = 85
islamiat = 90
maths = 95

# Total marks
total_marks = 300

# Calculate obtained marks
obtained_marks = english + islamiat + maths

# Calculate percentage
percentage = (obtained_marks / total_marks) * 100

# Display the result
print("English Marks:", english)
print("Islamiat Marks:", islamiat)
print("Maths Marks:", maths)
print("Total Marks:", total_marks)
print("Obtained Marks:", obtained_marks)
print("Percentage:", percentage, "%")
# Out:
# English Marks: 85
# Islamiat Marks: 90
# Maths Marks: 95
# Total Marks: 300
# Obtained Marks: 270
# Percentage: 90.0 %
